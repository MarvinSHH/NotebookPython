# %% [markdown]
# <a href="https://colab.research.google.com/github/MarvinSHH/NotebookPython/blob/main/Insects_10colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/juarezefren/datasets/refs/heads/main/insects-10.csv")
df.shape
# Out:
# (10, 4)

# %%
df
# Out:
#    id  abdomen  antena        clase
# 0   1      2.7     5.5  saltamontes
# 1   2      0.9     4.7  saltamontes
# 2   3      1.1     3.1  saltamontes
# 3   4      2.9     1.9  saltamontes
# 4   5      0.5     1.0  saltamontes
# 5   6      8.3     6.6    chicharra
# 6   7      8.1     4.7    chicharra
# 7   8      8.0     9.1    chicharra
# 8   9      5.4     8.5    chicharra
# 9  10      6.1     6.6    chicharra

# %%
df=df.sample(frac=1)
df
# Out:
#    id  abdomen  antena        clase
# 3   4      2.9     1.9  saltamontes
# 1   2      0.9     4.7  saltamontes
# 4   5      0.5     1.0  saltamontes
# 8   9      5.4     8.5    chicharra
# 2   3      1.1     3.1  saltamontes
# 6   7      8.1     4.7    chicharra
# 5   6      8.3     6.6    chicharra
# 9  10      6.1     6.6    chicharra
# 7   8      8.0     9.1    chicharra
# 0   1      2.7     5.5  saltamontes

# %%
x_train=df.iloc[:,1:-1]
x_train
# Out:
#    abdomen  antena
# 3      2.9     1.9
# 1      0.9     4.7
# 4      0.5     1.0
# 8      5.4     8.5
# 2      1.1     3.1
# 6      8.1     4.7
# 5      8.3     6.6
# 9      6.1     6.6
# 7      8.0     9.1
# 0      2.7     5.5

# %%
y_train=df.iloc[:-1]
y_train.head(4)
# Out:
#    id  abdomen  antena        clase
# 3   4      2.9     1.9  saltamontes
# 1   2      0.9     4.7  saltamontes
# 4   5      0.5     1.0  saltamontes
# 8   9      5.4     8.5    chicharra

# %%
from sklearn.svm import SVC
modelo=SVC()
modelo.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-900548df08d2> in <cell line: 0>()
#       1 from sklearn.svm import SVC
#       2 modelo=SVC()
# ----> 3 modelo.fit(x_train, y_train)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     195             check_consistent_length(X, y)
#     196         else:
# --> 197             X, y = validate_data(
#     198                 self,
#     199                 X,
#
# ...

# %%
x_test=pd.DataFrame({'Abdomen:[5.1]', 'antena:[7.0]'})
